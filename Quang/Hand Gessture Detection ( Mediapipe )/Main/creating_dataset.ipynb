# %% [markdown]
# # STEP 1: Set-up Directory

# %%
import cv2
import os
import random
import shutil

import mediapipe as mp
import matplotlib.pyplot as plt

import csv
import copy
import itertools
import numpy as np
import time

# %% [markdown]
# # STEP 2: Initialize directory

# %%
# data_dir = './dataset'

# if not os.path.exists(data_dir):
#     os.makedirs(data_dir)
#     print(f"Created directory: {data_dir}")
# else:
#     print(f"Directory already exists: {data_dir}")

# %% [markdown]
# # STEP 3: Input desire classes, dataset size = 500

# %%
# numb_of_classes = int(input("Enter the number of classes: "))
# dataset_size = 600
# train_size = 480  # Train size per class
# test_size = 120    # Test size per class

# %% [markdown]
# # STEP 4: Set-up camera capture image

# %% [markdown]
# ## Option 1: Only capture dataset with fixed size

# %%
# cap = cv2.VideoCapture(0)

# for i in range(numb_of_classes):
#     if not os.path.exists(os.path.join(data_dir, str(i))):
#         os.makedirs(os.path.join(data_dir, str(i)))
#     print(f"Collecting data for class: {i}")

#     done = False
#     while True:
#         ret, frame = cap.read()
#         cv2.putText(frame, 'For capturing data press q!', (0, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)
#         cv2.imshow('Frame', frame)
#         if cv2.waitKey(25) == ord('q'):
#             break

#     count = 0
#     while count < dataset_size:
#         ret, frame = cap.read()
#         cv2.imshow('Frame', frame)
#         cv2.waitKey(25)
#         cv2.imwrite(os.path.join(data_dir, str(i), '{}.jpg'.format(count)), frame)
        
#         count += 1

# cap.release()
# cv2.destroyAllWindows()

# %%
# import csv

# # Initialize MediaPipe hands solution
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)


# # Open the CSV file for writing
# with open('data.csv', 'w', newline='') as f:
#     writer = csv.writer(f)

#     # Write the header for the CSV file
#     writer.writerow(['Landmark_X', 'Landmark_Y', 'Label'])  # Adjust the header if necessary

#     # Loop over directories and images
#     for dir_ in os.listdir(data_dir):
#         for img_path in os.listdir(os.path.join(data_dir, dir_)):
#             data_aux = []
#             x_ = []
#             y_ = []

#             # Read and process the image
#             img = cv2.imread(os.path.join(data_dir, dir_, img_path))
#             img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#             results = hands.process(img_rgb)
#             if results.multi_hand_landmarks:
#                 for hand_landmarks in results.multi_hand_landmarks:
#                     # Collect the x and y coordinates of the landmarks
#                     for i in range(len(hand_landmarks.landmark)):
#                         x = hand_landmarks.landmark[i].x
#                         y = hand_landmarks.landmark[i].y

#                         x_.append(x)
#                         y_.append(y)

#                     # Normalize landmarks and append to data_aux
#                     for i in range(len(hand_landmarks.landmark)):
#                         x = hand_landmarks.landmark[i].x
#                         y = hand_landmarks.landmark[i].y
#                         data_aux.append(x - min(x_))
#                         data_aux.append(y - min(y_))

#                 # Write the flattened landmarks data and label to the CSV file
#                 # Add the label (directory name) at the end of the data
#                 data_aux.append(dir_)  # Append the label (dir_)
                
#                 # Write data row to CSV
#                 writer.writerow(data_aux)

# print("Data has been written to data.csv")

# %%
# import csv
# # Initialize MediaPipe hands solution
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

# # Open the CSV file for writing
# with open('data.csv', 'w', newline='') as f:
#     writer = csv.writer(f)

#     # Write the header for the CSV file
#     writer.writerow(['Label', 'Landmark_X', 'Landmark_Y'])  # 3 columns: Label, Landmark_X, Landmark_Y

#     # Loop over directories and images
#     for dir_ in os.listdir(data_dir):
#         for img_path in os.listdir(os.path.join(data_dir, dir_)):
#             # Read and process the image
#             img = cv2.imread(os.path.join(data_dir, dir_, img_path))
#             img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#             results = hands.process(img_rgb)
#             if results.multi_hand_landmarks:
#                 # Iterate through each hand found in the image
#                 for hand_landmarks in results.multi_hand_landmarks:
#                     # Collect the x and y coordinates of the landmarks
#                     for i in range(len(hand_landmarks.landmark)):
#                         x = hand_landmarks.landmark[i].x
#                         y = hand_landmarks.landmark[i].y
                        
#                         # Write each landmark as a new row with the label and its coordinates
#                         writer.writerow([dir_, x, y])  # Label is the directory, x and y are the landmark coordinates

# print("Data has been written to data.csv")

# %%
# import cv2
# import os
# import csv
# import mediapipe as mp  # Ensure mediapipe is imported

# # Initialize MediaPipe hands solution
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

# # Open the CSV file for writing
# with open('data.csv', 'w', newline='') as f:
#     writer = csv.writer(f)

#     # Write the header for the CSV file
#     writer.writerow(['Label', 'Landmark_X', 'Landmark_Y', 'Landmark_Z'])  # 4 columns: Label, Landmark_X, Landmark_Y, Landmark_Z

#     # Loop over directories and images
#     for dir_ in os.listdir(data_dir):
#         for img_path in os.listdir(os.path.join(data_dir, dir_)):
#             # Read and process the image
#             img = cv2.imread(os.path.join(data_dir, dir_, img_path))
#             image_height, image_width, _ = img.shape
#             img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#             results = hands.process(img_rgb)
            
#             # Check if landmarks are detected
#             if not results.multi_hand_landmarks:
#                 # If no landmarks detected, set all landmarks to zero
#                 landmarks = [
#                     ('WRIST', 0, 0, 0),
#                     ('THUMB_CMC', 0, 0, 0),
#                     ('THUMB_MCP', 0, 0, 0),
#                     ('THUMB_IP', 0, 0, 0),
#                     ('THUMB_TIP', 0, 0, 0),
#                     ('INDEX_FINGER_MCP', 0, 0, 0),
#                     ('INDEX_FINGER_PIP', 0, 0, 0),
#                     ('INDEX_FINGER_DIP', 0, 0, 0),
#                     ('INDEX_FINGER_TIP', 0, 0, 0),
#                     ('MIDDLE_FINGER_MCP', 0, 0, 0),
#                     ('MIDDLE_FINGER_PIP', 0, 0, 0),
#                     ('MIDDLE_FINGER_DIP', 0, 0, 0),
#                     ('MIDDLE_FINGER_TIP', 0, 0, 0),
#                     ('RING_FINGER_MCP', 0, 0, 0),
#                     ('RING_FINGER_PIP', 0, 0, 0),
#                     ('RING_FINGER_DIP', 0, 0, 0),
#                     ('RING_FINGER_TIP', 0, 0, 0),
#                     ('PINKY_MCP', 0, 0, 0),
#                     ('PINKY_PIP', 0, 0, 0),
#                     ('PINKY_DIP', 0, 0, 0),
#                     ('PINKY_TIP', 0, 0, 0)
#                 ]
#             else:
#                 # If landmarks detected, extract the coordinates of each landmark
#                 hand_landmarks = results.multi_hand_landmarks[0]
#                 landmarks = [
#                     ('WRIST', hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].z),
#                     ('THUMB_CMC', hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].z),
#                     ('THUMB_MCP', hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].z),
#                     ('THUMB_IP', hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].z),
#                     ('THUMB_TIP', hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].z),
#                     ('INDEX_FINGER_MCP', hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].z),
#                     ('INDEX_FINGER_PIP', hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].z),
#                     ('INDEX_FINGER_DIP', hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].z),
#                     ('INDEX_FINGER_TIP', hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].z),
#                     ('MIDDLE_FINGER_MCP', hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].z),
#                     ('MIDDLE_FINGER_PIP', hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].z),
#                     ('MIDDLE_FINGER_DIP', hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].z),
#                     ('MIDDLE_FINGER_TIP', hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].z),
#                     ('RING_FINGER_MCP', hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].z),
#                     ('RING_FINGER_PIP', hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].z),
#                     ('RING_FINGER_DIP', hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].z),
#                     ('RING_FINGER_TIP', hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].z),
#                     ('PINKY_MCP', hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].z),
#                     ('PINKY_PIP', hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].z),
#                     ('PINKY_DIP', hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].z),
#                     ('PINKY_TIP', hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].x * image_width,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].y * image_height,
#                         hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].z)
#                 ]
            
#             # Write the landmarks data to the CSV file
#             for landmark in landmarks:
#                 label = dir_  # The directory name is the label for this sample
#                 x = landmark[1]  # Landmark X
#                 y = landmark[2]  # Landmark Y
#                 z = landmark[3]  # Landmark Z
#                 writer.writerow([label, x, y, z])  # Write label, x, y, z to the CSV

# print("Data has been written to data.csv")

# %%
# # Initialize MediaPipe hands solution
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

# # Open the CSV file for writing
# with open('data1.csv', 'w', newline='') as f:
#     writer = csv.writer(f)

#     # Write the header for the CSV file with all landmark columns
#     header = [
#         'Label', 'wristX', 'wristY', 'wristZ',
#         'thumb_CmcX', 'thumb_CmcY', 'thumb_CmcZ',
#         'thumb_McpX', 'thumb_McpY', 'thumb_McpZ',
#         'thumb_IpX', 'thumb_IpY', 'thumb_IpZ',
#         'thumb_TipX', 'thumb_TipY', 'thumb_TipZ',
#         'index_McpX', 'index_McpY', 'index_McpZ',
#         'index_PipX', 'index_PipY', 'index_PipZ',
#         'index_DipX', 'index_DipY', 'index_DipZ',
#         'index_TipX', 'index_TipY', 'index_TipZ',
#         'middle_McpX', 'middle_McpY', 'middle_McpZ',
#         'middle_PipX', 'middle_PipY', 'middle_PipZ',
#         'middle_DipX', 'middle_DipY', 'middle_DipZ',
#         'middle_TipX', 'middle_TipY', 'middle_TipZ',
#         'ring_McpX', 'ring_McpY', 'ring_McpZ',
#         'ring_PipX', 'ring_PipY', 'ring_PipZ',
#         'ring_DipX', 'ring_DipY', 'ring_DipZ',
#         'ring_TipX', 'ring_TipY', 'ring_TipZ',
#         'pinky_McpX', 'pinky_McpY', 'pinky_McpZ',
#         'pinky_PipX', 'pinky_PipY', 'pinky_PipZ',
#         'pinky_DipX', 'pinky_DipY', 'pinky_DipZ',
#         'pinky_TipX', 'pinky_TipY', 'pinky_TipZ'
#     ]
    
#     writer.writerow(header)  # Write the header row
    
#     # Loop over directories and images
#     for dir_ in os.listdir(data_dir):
#         for img_path in os.listdir(os.path.join(data_dir, dir_)):
#             # Read and process the image
#             img = cv2.imread(os.path.join(data_dir, dir_, img_path))
#             image_height, image_width, _ = img.shape
#             img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#             results = hands.process(img_rgb)
            
#             # Prepare the data to be written for this image
#             row = [dir_]  # Add the label (which is the folder name)

#             if not results.multi_hand_landmarks:
#                 # If no landmarks are detected, append zeroes for all coordinates
#                 landmarks = [0] * 63  # There are 21 landmarks with x, y, z = 3 coordinates each
#                 row.extend(landmarks)  # Add zeroed landmarks to the row
#             else:
#                 # If landmarks are detected, extract the coordinates for each landmark
#                 hand_landmarks = results.multi_hand_landmarks[0]  # We take the first hand if there are multiple
                
#                 # For each of the landmarks, append the x, y, z values
#                 for landmark in [
#                     mp_hands.HandLandmark.WRIST,  # Wrist
#                     mp_hands.HandLandmark.THUMB_CMC,  # Thumb CMC
#                     mp_hands.HandLandmark.THUMB_MCP,  # Thumb MCP
#                     mp_hands.HandLandmark.THUMB_IP,  # Thumb IP
#                     mp_hands.HandLandmark.THUMB_TIP,  # Thumb Tip
#                     mp_hands.HandLandmark.INDEX_FINGER_MCP,  # Index MCP
#                     mp_hands.HandLandmark.INDEX_FINGER_PIP,  # Index PIP
#                     mp_hands.HandLandmark.INDEX_FINGER_DIP,  # Index DIP
#                     mp_hands.HandLandmark.INDEX_FINGER_TIP,  # Index Tip
#                     mp_hands.HandLandmark.MIDDLE_FINGER_MCP,  # Middle MCP
#                     mp_hands.HandLandmark.MIDDLE_FINGER_PIP,  # Middle PIP
#                     mp_hands.HandLandmark.MIDDLE_FINGER_DIP,  # Middle DIP
#                     mp_hands.HandLandmark.MIDDLE_FINGER_TIP,  # Middle Tip
#                     mp_hands.HandLandmark.RING_FINGER_MCP,  # Ring MCP
#                     mp_hands.HandLandmark.RING_FINGER_PIP,  # Ring PIP
#                     mp_hands.HandLandmark.RING_FINGER_DIP,  # Ring DIP
#                     mp_hands.HandLandmark.RING_FINGER_TIP,  # Ring Tip
#                     mp_hands.HandLandmark.PINKY_MCP,  # Pinky MCP
#                     mp_hands.HandLandmark.PINKY_PIP,  # Pinky PIP
#                     mp_hands.HandLandmark.PINKY_DIP,  # Pinky DIP
#                     mp_hands.HandLandmark.PINKY_TIP   # Pinky Tip
#                 ]:
#                     # Extract the x, y, z coordinates and scale them to the image size
#                     x = hand_landmarks.landmark[landmark].x * image_width
#                     y = hand_landmarks.landmark[landmark].y * image_height
#                     z = hand_landmarks.landmark[landmark].z
                    
#                     # Append the coordinates to the row
#                     row.extend([x, y, z])
            
#             # Write the row to the CSV
#             writer.writerow(row)

# print("Data has been written to data.csv")

# %%
# mp_hands = mp.solutions.hands
# mp_drawing = mp.solutions.drawing_utils
# mp_drawing_styles = mp.solutions.drawing_styles

# hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

# for dir_ in os.listdir(data_dir):
#     for img_path in os.listdir(os.path.join(data_dir, dir_))[:1]:
#         img = cv2.imread(os.path.join(data_dir, dir_, img_path))
#         img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#         results = hands.process(img_rgb)

#         if results.multi_hand_landmarks:
#             for hand_landmarks in results.multi_hand_landmarks:
#                 mp_drawing.draw_landmarks(
#                     img_rgb,
#                     hand_landmarks,
#                     mp_hands.HAND_CONNECTIONS
#                 )


#         plt.figure()
#         plt.imshow(img_rgb)

# plt.show

# %% [markdown]
# ## Option 2: Capture image and split data (Full + Train + Test)

# %% [markdown]
# ### Vers 1: Overwriting folder is negligible

# %%
# # Create the base "Full", "Train", and "Test" folders
# full_dir = os.path.join(data_dir, 'Full')
# train_dir = os.path.join(data_dir, 'Train')
# test_dir = os.path.join(data_dir, 'Test')

# os.makedirs(full_dir, exist_ok=True)
# os.makedirs(train_dir, exist_ok=True)
# os.makedirs(test_dir, exist_ok=True)

# # Video capture setup
# cap = cv2.VideoCapture(0)

# # Image collection for each class
# for i in range(numb_of_classes):
#     # Directories for class images in Full folder
#     class_full_dir = os.path.join(full_dir, str(i))
#     os.makedirs(class_full_dir, exist_ok=True)
    
#     print(f"Collecting data for class: {i}")
    
#     done = False
#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             print("Failed to capture video frame. Exiting.")
#             break

#         # Display instructions
#         cv2.putText(frame, 'Press q to start capturing for this class!', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
#         cv2.imshow('Frame', frame)
        
#         # Wait for user to press 'q' to start capturing
#         if cv2.waitKey(25) == ord('q'):
#             break

#     count = 0
#     while count < dataset_size:
#         ret, frame = cap.read()
#         if not ret:
#             print("Failed to capture video frame. Exiting.")
#             break
        
#         cv2.imshow('Frame', frame)
#         # Save each image in the "Full" directory
#         cv2.imwrite(os.path.join(class_full_dir, f'{count}.jpg'), frame)
#         count += 1

#         # Exit capturing if user presses 'q'
#         if cv2.waitKey(1) == ord('q'):
#             break

#     print(f"Finished collecting data for class {i}.")

# cap.release()
# cv2.destroyAllWindows()

# # Dataset splitting into Train and Test folders
# print("\nSplitting dataset into Train and Test folders...")

# for class_folder in os.listdir(full_dir):
#     class_path = os.path.join(full_dir, class_folder)

#     # Skip the Train and Test folders themselves
#     if not os.path.isdir(class_path):
#         continue

#     # Create class-specific subdirectories in Train and Test
#     train_class_dir = os.path.join(train_dir, class_folder)
#     test_class_dir = os.path.join(test_dir, class_folder)
#     os.makedirs(train_class_dir, exist_ok=True)
#     os.makedirs(test_class_dir, exist_ok=True)

#     # Get all images in the class folder
#     images = os.listdir(class_path)
#     random.shuffle(images)  # Shuffle for randomness

#     # Split into train and test sets
#     train_images = images[:train_size]
#     test_images = images[train_size:train_size + test_size]

#     # Copy images to Train and Test directories
#     for img in train_images:
#         shutil.copy(os.path.join(class_path, img), os.path.join(train_class_dir, img))
#     for img in test_images:
#         shutil.copy(os.path.join(class_path, img), os.path.join(test_class_dir, img))

#     print(f"Class '{class_folder}' split into Train ({len(train_images)}) and Test ({len(test_images)}).")

# print("Dataset creation and splitting complete.")

# %% [markdown]
# ### Vers 2: Overwriting folder is included

# %%
# # Remove the existing 'dataset' folder if it exists, to overwrite it
# if os.path.exists(data_dir):
#     print(f"Existing dataset folder found. Deleting {data_dir}...")
#     shutil.rmtree(data_dir)

# # Create the base "Full", "Train", and "Test" folders
# full_dir = os.path.join(data_dir, 'Full')
# train_dir = os.path.join(data_dir, 'Train')
# test_dir = os.path.join(data_dir, 'Test')

# os.makedirs(full_dir, exist_ok=True)
# os.makedirs(train_dir, exist_ok=True)
# os.makedirs(test_dir, exist_ok=True)

# # Video capture setup
# cap = cv2.VideoCapture(0)

# # Image collection for each class
# for i in range(numb_of_classes):
#     # Directories for class images in Full folder
#     class_full_dir = os.path.join(full_dir, str(i))
#     os.makedirs(class_full_dir, exist_ok=True)
    
#     print(f"Collecting data for class: {i}")
    
#     done = False
#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             print("Failed to capture video frame. Exiting.")
#             break

#         # Display instructions
#         cv2.putText(frame, 'Press q to start capturing for this class!', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
#         cv2.imshow('Frame', frame)
        
#         # Wait for user to press 'q' to start capturing
#         if cv2.waitKey(25) == ord('q'):
#             break

#     count = 0
#     while count < dataset_size:
#         ret, frame = cap.read()
#         if not ret:
#             print("Failed to capture video frame. Exiting.")
#             break
        
#         cv2.imshow('Frame', frame)
#         # Save each image in the "Full" directory
#         cv2.imwrite(os.path.join(class_full_dir, f'{count}.jpg'), frame)
#         count += 1

#         # Exit capturing if user presses 'q'
#         if cv2.waitKey(1) == ord('q'):
#             break

#     print(f"Finished collecting data for class {i}.")

# cap.release()
# cv2.destroyAllWindows()

# # Dataset splitting into Train and Test folders
# print("\nSplitting dataset into Train and Test folders...")

# for class_folder in os.listdir(full_dir):
#     class_path = os.path.join(full_dir, class_folder)

#     # Skip the Train and Test folders themselves
#     if not os.path.isdir(class_path):
#         continue

#     # Create class-specific subdirectories in Train and Test
#     train_class_dir = os.path.join(train_dir, class_folder)
#     test_class_dir = os.path.join(test_dir, class_folder)
#     os.makedirs(train_class_dir, exist_ok=True)
#     os.makedirs(test_class_dir, exist_ok=True)

#     # Get all images in the class folder
#     images = os.listdir(class_path)
#     random.shuffle(images)  # Shuffle for randomness

#     # Split into train and test sets
#     train_images = images[:train_size]
#     test_images = images[train_size:train_size + test_size]

#     # Copy images to Train and Test directories
#     for img in train_images:
#         shutil.copy(os.path.join(class_path, img), os.path.join(train_class_dir, img))
#     for img in test_images:
#         shutil.copy(os.path.join(class_path, img), os.path.join(test_class_dir, img))

#     print(f"Class '{class_folder}' split into Train ({len(train_images)}) and Test ({len(test_images)}).")

# print("Dataset creation and splitting complete.")

# %%
# # Initialize MediaPipe hands solution
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

# # Initialize CSV file for writing
# def process_images_from_directory(directory, csv_filename):
#     """Process images in a given directory and write to a CSV file."""
#     csv_path = os.path.join(data_dir, csv_filename)
#     with open(csv_path, 'w', newline='') as f:
#         writer = csv.writer(f)

#         # Write the header for the CSV file with all landmark columns
#         header = [
#             'Label', 'wristX', 'wristY', 'wristZ',
#             'thumb_CmcX', 'thumb_CmcY', 'thumb_CmcZ',
#             'thumb_McpX', 'thumb_McpY', 'thumb_McpZ',
#             'thumb_IpX', 'thumb_IpY', 'thumb_IpZ',
#             'thumb_TipX', 'thumb_TipY', 'thumb_TipZ',
#             'index_McpX', 'index_McpY', 'index_McpZ',
#             'index_PipX', 'index_PipY', 'index_PipZ',
#             'index_DipX', 'index_DipY', 'index_Dz',
#             'index_TipX', 'index_TipY', 'index_TipZ',
#             'middle_McpX', 'middle_McpY', 'middle_McpZ',
#             'middle_PipX', 'middle_PipY', 'middle_PipZ',
#             'middle_DipX', 'middle_DipY', 'middle_DipZ',
#             'middle_TipX', 'middle_TipY', 'middle_TipZ',
#             'ring_McpX', 'ring_McpY', 'ring_McpZ',
#             'ring_PipX', 'ring_PipY', 'ring_PipZ',
#             'ring_DipX', 'ring_DipY', 'ring_DipZ',
#             'ring_TipX', 'ring_TipY', 'ring_TipZ',
#             'pinky_McpX', 'pinky_McpY', 'pinky_McpZ',
#             'pinky_PipX', 'pinky_PipY', 'pinky_PipZ',
#             'pinky_DipX', 'pinky_DipY', 'pinky_DipZ',
#             'pinky_TipX', 'pinky_TipY', 'pinky_TipZ'
#         ]
#         writer.writerow(header)  # Write the header row

#         # Loop through all directories in the provided directory
#         for class_folder in os.listdir(directory):
#             class_path = os.path.join(directory, class_folder)
#             if not os.path.isdir(class_path):  # Skip non-directories
#                 continue

#             # Process each image in the class folder
#             for img_name in os.listdir(class_path):
#                 img_path = os.path.join(class_path, img_name)
#                 img = cv2.imread(img_path)
#                 if img is None:
#                     continue  # Skip invalid images

#                 image_height, image_width, _ = img.shape
#                 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#                 # Process the image to detect landmarks
#                 results = hands.process(img_rgb)

#                 # Prepare the data row
#                 row = [class_folder]  # Add the label (folder name)

#                 if not results.multi_hand_landmarks:
#                     # If no landmarks are detected, append zeroes for all coordinates
#                     landmarks = [0] * 63  # 21 landmarks with x, y, z coordinates
#                     row.extend(landmarks)  # Add zeroed landmarks to the row
#                 else:
#                     # Process the detected landmarks
#                     hand_landmarks = results.multi_hand_landmarks[0]  # We take the first hand if multiple hands are detected
                    
#                     # Iterate through the predefined landmarks
#                     for landmark in [
#                         mp_hands.HandLandmark.WRIST,  # Wrist
#                         mp_hands.HandLandmark.THUMB_CMC,  # Thumb CMC
#                         mp_hands.HandLandmark.THUMB_MCP,  # Thumb MCP
#                         mp_hands.HandLandmark.THUMB_IP,  # Thumb IP
#                         mp_hands.HandLandmark.THUMB_TIP,  # Thumb Tip
#                         mp_hands.HandLandmark.INDEX_FINGER_MCP,  # Index MCP
#                         mp_hands.HandLandmark.INDEX_FINGER_PIP,  # Index PIP
#                         mp_hands.HandLandmark.INDEX_FINGER_DIP,  # Index DIP
#                         mp_hands.HandLandmark.INDEX_FINGER_TIP,  # Index Tip
#                         mp_hands.HandLandmark.MIDDLE_FINGER_MCP,  # Middle MCP
#                         mp_hands.HandLandmark.MIDDLE_FINGER_PIP,  # Middle PIP
#                         mp_hands.HandLandmark.MIDDLE_FINGER_DIP,  # Middle DIP
#                         mp_hands.HandLandmark.MIDDLE_FINGER_TIP,  # Middle Tip
#                         mp_hands.HandLandmark.RING_FINGER_MCP,  # Ring MCP
#                         mp_hands.HandLandmark.RING_FINGER_PIP,  # Ring PIP
#                         mp_hands.HandLandmark.RING_FINGER_DIP,  # Ring DIP
#                         mp_hands.HandLandmark.RING_FINGER_TIP,  # Ring Tip
#                         mp_hands.HandLandmark.PINKY_MCP,  # Pinky MCP
#                         mp_hands.HandLandmark.PINKY_PIP,  # Pinky PIP
#                         mp_hands.HandLandmark.PINKY_DIP,  # Pinky DIP
#                         mp_hands.HandLandmark.PINKY_TIP   # Pinky Tip
#                     ]:
#                         # Extract x, y, z coordinates and scale them to the image size
#                         x = hand_landmarks.landmark[landmark].x * image_width
#                         y = hand_landmarks.landmark[landmark].y * image_height
#                         z = hand_landmarks.landmark[landmark].z

#                         # Append the coordinates to the row
#                         row.extend([x, y, z])

#                 # Write the row to the CSV
#                 writer.writerow(row)

# %%
# # Process "Full", "Train", and "Test" folders
# try:
#     print("Processing Full folder...")
#     process_images_from_directory(os.path.join(data_dir, 'Full'), 'full.csv')
# except Exception as e:
#     print(f"Failed to process Full folder: {e}")

# try:
#     print("Processing Train folder...")
#     process_images_from_directory(os.path.join(data_dir, 'Train'), 'train_data.csv')
# except Exception as e:
#     print(f"Failed to process Train folder: {e}")

# try:
#     print("Processing Test folder...")
#     process_images_from_directory(os.path.join(data_dir, 'Test'), 'test_data.csv')
# except Exception as e:
#     print(f"Failed to process Test folder: {e}")

# print("CSV files have been written: full.csv, train_data.csv, test_data.csv")

# %%
# # Initialize MediaPipe hands solution
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

# # Initialize CSV file for writing
# def process_images_from_directory_2(directory, csv_filename):
#     """Process images in a given directory and write to a CSV file."""
#     csv_path = os.path.join(data_dir, csv_filename)
#     with open(csv_path, 'w', newline='') as f:
#         writer = csv.writer(f)

#         # Write the header for the CSV file with all landmark columns
#         header = [
#             'Label', 'wristX', 'wristY', 'wristZ',
#             'thumb_CmcX', 'thumb_CmcY', 'thumb_CmcZ',
#             'thumb_McpX', 'thumb_McpY', 'thumb_McpZ',
#             'thumb_IpX', 'thumb_IpY', 'thumb_IpZ',
#             'thumb_TipX', 'thumb_TipY', 'thumb_TipZ',
#             'index_McpX', 'index_McpY', 'index_McpZ',
#             'index_PipX', 'index_PipY', 'index_PipZ',
#             'index_DipX', 'index_DipY', 'index_Dz',
#             'index_TipX', 'index_TipY', 'index_TipZ',
#             'middle_McpX', 'middle_McpY', 'middle_McpZ',
#             'middle_PipX', 'middle_PipY', 'middle_PipZ',
#             'middle_DipX', 'middle_DipY', 'middle_DipZ',
#             'middle_TipX', 'middle_TipY', 'middle_TipZ',
#             'ring_McpX', 'ring_McpY', 'ring_McpZ',
#             'ring_PipX', 'ring_PipY', 'ring_PipZ',
#             'ring_DipX', 'ring_DipY', 'ring_DipZ',
#             'ring_TipX', 'ring_TipY', 'ring_TipZ',
#             'pinky_McpX', 'pinky_McpY', 'pinky_McpZ',
#             'pinky_PipX', 'pinky_PipY', 'pinky_PipZ',
#             'pinky_DipX', 'pinky_DipY', 'pinky_DipZ',
#             'pinky_TipX', 'pinky_TipY', 'pinky_TipZ'
#         ]
#         writer.writerow(header)  # Write the header row

#         # Loop through all directories in the provided directory
#         for class_folder in os.listdir(directory):
#             class_path = os.path.join(directory, class_folder)
#             if not os.path.isdir(class_path):  # Skip non-directories
#                 continue

#             # Process each image in the class folder
#             for img_name in os.listdir(class_path):
#                 img_path = os.path.join(class_path, img_name)
#                 img = cv2.imread(img_path)
#                 if img is None:
#                     continue  # Skip invalid images

#                 image_height, image_width, _ = img.shape
#                 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#                 # Process the image to detect landmarks
#                 results = hands.process(img_rgb)

#                 # Prepare the data row
#                 row = [class_folder]  # Add the label (folder name)

#                 if not results.multi_hand_landmarks:
#                     # If no landmarks are detected, append zeroes for all coordinates
#                     landmarks = [0] * 63  # 21 landmarks with x, y, z coordinates
#                     row.extend(landmarks)  # Add zeroed landmarks to the row
#                 else:
#                     # Process the detected landmarks
#                     hand_landmarks = results.multi_hand_landmarks[0]  # We take the first hand if multiple hands are detected
                    
#                     # Iterate through the predefined landmarks
#                     for landmark in [
#                         mp_hands.HandLandmark.WRIST,  # Wrist
#                         mp_hands.HandLandmark.THUMB_CMC,  # Thumb CMC
#                         mp_hands.HandLandmark.THUMB_MCP,  # Thumb MCP
#                         mp_hands.HandLandmark.THUMB_IP,  # Thumb IP
#                         mp_hands.HandLandmark.THUMB_TIP,  # Thumb Tip
#                         mp_hands.HandLandmark.INDEX_FINGER_MCP,  # Index MCP
#                         mp_hands.HandLandmark.INDEX_FINGER_PIP,  # Index PIP
#                         mp_hands.HandLandmark.INDEX_FINGER_DIP,  # Index DIP
#                         mp_hands.HandLandmark.INDEX_FINGER_TIP,  # Index Tip
#                         mp_hands.HandLandmark.MIDDLE_FINGER_MCP,  # Middle MCP
#                         mp_hands.HandLandmark.MIDDLE_FINGER_PIP,  # Middle PIP
#                         mp_hands.HandLandmark.MIDDLE_FINGER_DIP,  # Middle DIP
#                         mp_hands.HandLandmark.MIDDLE_FINGER_TIP,  # Middle Tip
#                         mp_hands.HandLandmark.RING_FINGER_MCP,  # Ring MCP
#                         mp_hands.HandLandmark.RING_FINGER_PIP,  # Ring PIP
#                         mp_hands.HandLandmark.RING_FINGER_DIP,  # Ring DIP
#                         mp_hands.HandLandmark.RING_FINGER_TIP,  # Ring Tip
#                         mp_hands.HandLandmark.PINKY_MCP,  # Pinky MCP
#                         mp_hands.HandLandmark.PINKY_PIP,  # Pinky PIP
#                         mp_hands.HandLandmark.PINKY_DIP,  # Pinky DIP
#                         mp_hands.HandLandmark.PINKY_TIP   # Pinky Tip
#                     ]:
#                         # Extract x, y, z coordinates and scale them to the image size
#                         x = hand_landmarks.landmark[landmark].x * image_width
#                         y = hand_landmarks.landmark[landmark].y * image_height
#                         z = hand_landmarks.landmark[landmark].z

#                         # Append the coordinates to the row
#                         row.extend([x, y, z])

#                 # Write the row to the CSV
#                 writer.writerow(row)


# # Process "Full", "Train", and "Test" folders
# try:
#     print("Processing Full folder...")
#     process_images_from_directory(os.path.join(data_dir, 'Full'), 'full_2.csv')
# except Exception as e:
#     print(f"Failed to process Full folder: {e}")

# # try:
# #     print("Processing Train folder...")
# #     process_images_from_directory(os.path.join(data_dir, 'Train'), 'train_data_2.csv')
# # except Exception as e:
# #     print(f"Failed to process Train folder: {e}")

# # try:
# #     print("Processing Test folder...")
# #     process_images_from_directory(os.path.join(data_dir, 'Test'), 'test_data_2.csv')
# # except Exception as e:
# #     print(f"Failed to process Test folder: {e}")

# print("CSV files have been written: full_2.csv, train_data_2.csv, test_data_2.csv")

# %% [markdown]
# ## Option 3: For specific task

# %% [markdown]
# ### Main idea

# %%
def select_mode(key):
    number = -1

    # if 48 <= key <= 57:  # 0 ~ 9
    #     number = key - 48
    # if key == 110:  # n
    #     mode = 0
    if key == 107:  # k
        mode = 1
    else:
        mode = 0
    return  mode

# %%
def logging_csv(number, mode, landmark_list): 
    # if mode == 0:
    #     pass
    if mode == 1 and (0 <= number <= 9):
        csv_path = 'new_keypoint.csv'
        
        # Check if the file exists, if not, create it
        if not os.path.exists(csv_path):
            with open(csv_path, 'w', newline="") as f:
                writer = csv.writer(f)
                # The file will be created but no header is written, just ready to append data

        # Append the data to the CSV file
        with open(csv_path, 'a', newline="") as f:
            writer = csv.writer(f)
            writer.writerow([number, *landmark_list])
    return

# %%
def calc_landmark_list(image, landmarks):
    image_width, image_height = image.shape[1], image.shape[0]

    landmark_point = []

    # Keypoint
    for _, landmark in enumerate(landmarks.landmark):
        landmark_x = min(int(landmark.x * image_width), image_width - 1)
        landmark_y = min(int(landmark.y * image_height), image_height - 1)
        # landmark_z = landmark.z

        landmark_point.append([landmark_x, landmark_y])

    return landmark_point

# %%
def pre_process_landmark(landmark_list):
    temp_landmark_list = copy.deepcopy(landmark_list)

    # Convert to relative coordinates
    base_x, base_y = 0, 0
    for index, landmark_point in enumerate(temp_landmark_list):
        if index == 0:
            base_x, base_y = landmark_point[0], landmark_point[1]

        temp_landmark_list[index][0] = temp_landmark_list[index][0] - base_x
        temp_landmark_list[index][1] = temp_landmark_list[index][1] - base_y

    # Convert to a one-dimensional list
    temp_landmark_list = list(itertools.chain.from_iterable(temp_landmark_list))

    # Normalization
    max_value = max(list(map(abs, temp_landmark_list)))

    def normalize_(n):
        return n / max_value

    temp_landmark_list = list(map(normalize_, temp_landmark_list))

    return temp_landmark_list

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('new_keypoint.csv', header=None)

# Display the first few rows of the DataFrame
df[0].max()
# Out:
# 3

# %%
# ------------------------------------------
# Tuaan modification
# ------------------------------------------

import cv2
import mediapipe as mp
import pandas as pd

# Initialize video capture
cap = cv2.VideoCapture(0)

# Check if the camera opened successfully
if not cap.isOpened():
    print("Error: Unable to access the camera.")
    exit()

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(
    static_image_mode=True,  # Whether to process each frame as a static image
    max_num_hands=1,  # Number of hands to detect
    min_detection_confidence=0.7,  # Minimum confidence value for detecting hands
    min_tracking_confidence=0.5  # Minimum confidence value for hand tracking
)




mode = 0
recCount = 0

# Process video frames
while True:
    if recCount == 10: 
        recCount = 0
        mode = 0

    """Process Key (ESC: end)"""
    key = cv2.waitKey(10)
    if key == 27:  # ESC
        break
    # mode = select_mode(key) 
    elif key == 107:  # k
        mode = 1
    # else:
    #     mode = 0

    # press K for capturing keypoint (0-9)

    # if mode == 1: 
    #     # df = pd.read_csv('new_keypoint.csv', header=None)
    #     # number = df[0].max() + 1
    #     number = 4
    #     recCount += 1
    #     cv2.putText(frame, 'hand record activated ', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)




    ret, frame = cap.read()
    if not ret:
        print("Failed to capture frame. Exiting.")
        break

    frame = cv2.flip(frame, 1) # Mirror the frame
    debug_frame = copy.deepcopy(frame)

    # Convert the frame to RGB (MediaPipe requires RGB)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform hand detection
    results = hands.process(frame_rgb)

    # If hands are detected, draw landmarks on the frame
    if results.multi_hand_landmarks:
        for hand_landmarks, handedness in zip(results.multi_hand_landmarks, results.multi_handedness):

            # print(hand_landmarks)

            # Landmark calculation
            Landmark_list = calc_landmark_list(debug_frame, hand_landmarks)
            # print(Landmark_list[0])

            # Conversion to relative coordinates / normalized coordinates
            pre_processed_landmark_list = pre_process_landmark(Landmark_list)
            # print(pre_processed_landmark_list)

            if recCount < 10:
                number = 4
                recCount += 1
                cv2.putText(frame, 'hand record activated', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)

                # Write to the dataset file
                logging_csv(number, mode, pre_processed_landmark_list) 

            # Draw the landmarks
            mp.solutions.drawing_utils.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    # Display instructions
    cv2.putText(frame, 'Press esc to exit ', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
    cv2.imshow('Frame', frame)


# Release the capture object and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\dangq\AppData\Local\Programs\Python\Python310\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
import cv2
import mediapipe as mp

# Initialize video capture
cap = cv2.VideoCapture(0)

# Check if the camera opened successfully
if not cap.isOpened():
    print("Error: Unable to access the camera.")
    exit()

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(
    static_image_mode=True,  # Whether to process each frame as a static image
    max_num_hands=1,  # Number of hands to detect
    min_detection_confidence=0.7,  # Minimum confidence value for detecting hands
    min_tracking_confidence=0.5  # Minimum confidence value for hand tracking
)

mode = 0

# Process video frames
while True:
    
    """Process Key (ESC: end)"""
    key = cv2.waitKey(10)
    if key == 27:  # ESC
        break
    number, mode = select_mode(key, mode) 
    # press K for capturing keypoint (0-9)
    if mode == 1: 
        cv2.putText(frame, 'hand record activated ', (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)



    ret, frame = cap.read()
    if not ret:
        print("Failed to capture frame. Exiting.")
        break

    frame = cv2.flip(frame, 1) # Mirror the frame
    debug_frame = copy.deepcopy(frame)

    # Convert the frame to RGB (MediaPipe requires RGB)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Perform hand detection
    results = hands.process(frame_rgb)

    # If hands are detected, draw landmarks on the frame
    if results.multi_hand_landmarks:
        for hand_landmarks, handedness in zip(results.multi_hand_landmarks, results.multi_handedness):

            # print(hand_landmarks)

            # Landmark calculation
            Landmark_list = calc_landmark_list(debug_frame, hand_landmarks)
            # print(Landmark_list[0])

            # Conversion to relative coordinates / normalized coordinates
            pre_processed_landmark_list = pre_process_landmark(Landmark_list)
            # print(pre_processed_landmark_list)

            # Write to the dataset file
            logging_csv(number, mode, pre_processed_landmark_list) 

            # Draw the landmarks
            mp.solutions.drawing_utils.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    # Display instructions
    cv2.putText(frame, 'Press q to exit ', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
    cv2.imshow('Frame', frame)


# Release the capture object and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# [0.0, 0.0, -0.2037037037037037, 0.0, -0.39814814814814814, 0.0, -0.5231481481481481, -0.10648148148148148, -0.5879629629629629, -0.2824074074074074, -0.24074074074074073, -0.23148148148148148, -0.36574074074074076, -0.5416666666666666, -0.4444444444444444, -0.7314814814814815, -0.5046296296296297, -0.8888888888888888, -0.06018518518518518, -0.25925925925925924, -0.10185185185185185, -0.6111111111111112, -0.13425925925925927, -0.8240740740740741, -0.16666666666666666, -1.0, 0.12037037037037036, -0.21296296296296297, 0.12037037037037036, -0.5648148148148148, 0.12037037037037036, -0.7685185185185185, 0.11574074074074074, -0.9444444444444444, 0.2916666666666667, -0.1111111111111111, 0.375, -0.36574074074074076, 0.42592592592592593, -0.5324074074074074, 0.4537037037037037, -0.6759259259259259]
# ...

# %% [markdown]
# ### Prototype

# %%
# def select_mode(key, mode):
#     number = -1
#     if 48 <= key <= 57:  # 0 ~ 9
#         number = key - 48
#     if key == 110:  # n
#         mode = 0
#     if key == 107:  # k
#         mode = 1
#     if key == 115:  # s
#         mode = 2
#     return number, mode

# %%
# def logging_csv(number, mode, landmark_list): 
#     if mode == 0:
#         pass
#     if mode == 1 and (0 <= number <= 9) : 
#         csv_path = 'new_keypoint.csv'
        
#         # Check if the file exists, if not, create it
#         if not os.path.exists(csv_path):
#             with open(csv_path, 'w', newline="") as f:
#                 writer = csv.writer(f)
#                 # The file will be created but no header is written, just ready to append data

#         # Append the data to the CSV file
#         with open(csv_path, 'a', newline="") as f:
#             writer = csv.writer(f)
#             writer.writerow([number, *landmark_list])
        
#     if mode == 2 and (0 <= number <= 9):
#         csv_path = 'new_keypoint_1.csv'
        
#         # Check if the file exists, if not, create it
#         if not os.path.exists(csv_path):
#             with open(csv_path, 'w', newline="") as f:
#                 writer = csv.writer(f)
#                 # The file will be created but no header is written, just ready to append data

#         # Append the data to the CSV file
#         with open(csv_path, 'a', newline="") as f:
#             writer = csv.writer(f)
#             writer.writerow([number, *landmark_list])
#     return

# %%
# def calc_landmark_list(image, landmarks):
#     image_width, image_height = image.shape[1], image.shape[0]

#     landmark_point = []

#     # Keypoint
#     for _, landmark in enumerate(landmarks.landmark):
#         landmark_x = min(int(landmark.x * image_width), image_width - 1)
#         landmark_y = min(int(landmark.y * image_height), image_height - 1)
#         # landmark_z = landmark.z

#         landmark_point.append([landmark_x, landmark_y])

#     return landmark_point

# %%
# import cv2
# import mediapipe as mp

# # Initialize video capture
# cap = cv2.VideoCapture(0)

# # Check if the camera opened successfully
# if not cap.isOpened():
#     print("Error: Unable to access the camera.")
#     exit()

# # Initialize MediaPipe Hands
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(
#     static_image_mode=True,  # Whether to process each frame as a static image
#     max_num_hands=1,  # Number of hands to detect
#     min_detection_confidence=0.7,  # Minimum confidence value for detecting hands
#     min_tracking_confidence=0.5  # Minimum confidence value for hand tracking
# )

# mode = 0
# row_count = 0
# row_10 = []

# while True:
#     """Process Key (ESC: end)"""
#     key = cv2.waitKey(10)
#     if key == 27:  # ESC
#         break
#     number, mode = select_mode(key, mode)

#     ret, frame = cap.read()
#     if not ret:
#         print("Failed to capture frame. Exiting.")
#         break

#     frame = cv2.flip(frame, 1)  # Mirror the frame
#     debug_frame = copy.deepcopy(frame)

#     # Convert the frame to RGB (MediaPipe requires RGB)
#     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     # Perform hand detection
#     results = hands.process(frame_rgb)

#     # If hands are detected, draw landmarks on the frame
#     if results.multi_hand_landmarks:
#         for hand_landmarks, handedness in zip(results.multi_hand_landmarks, results.multi_handedness):
#             # Calculate the landmark list for each hand
#             Landmark_list = calc_landmark_list(debug_frame, hand_landmarks)
            
#             # Pre-process the landmark list (e.g., normalize)
#             pre_processed_landmark_list = pre_process_landmark(Landmark_list)

#             # # Write to the dataset file

            
#             # if mode == 2 and number == 0:
#             #     for row_count in range(10):
#             #         print(pre_processed_landmark_list)
#             #         row_count += 1


#             if number == 0:
#                 # if row_count < 10:
#                 print(pre_processed_landmark_list)
#                 # logging_csv(number, mode, pre_processed_landmark_list)

#             # Draw the landmarks
#             mp.solutions.drawing_utils.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

#     # Display instructions
#     cv2.putText(frame, 'Press esc to exit ', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
#     cv2.imshow('Frame', frame)

# # Release the capture object and close windows
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# Ngon phan print

# %%
# import cv2
# import mediapipe as mp
# import os
# import csv
# import copy

# # Initialize video capture
# cap = cv2.VideoCapture(0)

# # Check if the camera opened successfully
# if not cap.isOpened():
#     print("Error: Unable to access the camera.")
#     exit()

# # Initialize MediaPipe Hands
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(
#     static_image_mode=True,  # Whether to process each frame as a static image
#     max_num_hands=1,  # Number of hands to detect
#     min_detection_confidence=0.7,  # Minimum confidence value for detecting hands
#     min_tracking_confidence=0.5  # Minimum confidence value for hand tracking
# )

# # Initialize variables
# mode = 0
# capture_count = 0  # Counter for number of captures
# max_captures = 10  # Maximum number of captures
# capturing = False  # Flag to indicate if we are in capturing mode

# def select_mode(key, mode):
#     number = -1

#     if 48 <= key <= 57:  # 0 ~ 9
#         number = key - 48
#     if key == 110:  # n
#         mode = 0
#     if key == 107:  # k
#         mode = 1
#     if key == 115:  # s
#         mode = 2
#     return number, mode

# def logging_csv(number, mode, landmark_list): 
#     if mode == 2 and (0 <= number <= 9):  # Only write when mode is 2
#         csv_path = 'new_keypoint_1.csv'  # CSV file for mode 2
        
#         # Check if the file exists, if not, create it
#         if not os.path.exists(csv_path):
#             with open(csv_path, 'w', newline="") as f:
#                 writer = csv.writer(f)

#         # Append the data to the CSV file
#         with open(csv_path, 'a', newline="") as f:
#             writer = csv.writer(f)
#             writer.writerow([number, *landmark_list])  # Write number and landmarks
        
#     return

# def pre_process_landmark(landmark_list):
#     temp_landmark_list = copy.deepcopy(landmark_list)

#     # Convert to relative coordinates
#     base_x, base_y = 0, 0
#     for index, landmark_point in enumerate(temp_landmark_list):
#         if index == 0:
#             base_x, base_y = landmark_point[0], landmark_point[1]

#         temp_landmark_list[index][0] = temp_landmark_list[index][0] - base_x
#         temp_landmark_list[index][1] = temp_landmark_list[index][1] - base_y

#     # Convert to a one-dimensional list
#     temp_landmark_list = list(itertools.chain.from_iterable(temp_landmark_list))

#     # Normalization
#     max_value = max(list(map(abs, temp_landmark_list)))

#     def normalize_(n):
#         return n / max_value

#     temp_landmark_list = list(map(normalize_, temp_landmark_list))

#     return temp_landmark_list

# def calc_landmark_list(image, landmarks):
#     image_width, image_height = image.shape[1], image.shape[0]

#     landmark_point = []

#     # Keypoint
#     for _, landmark in enumerate(landmarks.landmark):
#         landmark_x = min(int(landmark.x * image_width), image_width - 1)
#         landmark_y = min(int(landmark.y * image_height), image_height - 1)

#         landmark_point.append([landmark_x, landmark_y])

#     return landmark_point

# while True:
#     """Process Key (ESC: end)"""
#     key = cv2.waitKey(10)
#     if key == 27:  # ESC
#         break
#     number, mode = select_mode(key, mode)

#     ret, frame = cap.read()
#     if not ret:
#         print("Failed to capture frame. Exiting.")
#         break

#     frame = cv2.flip(frame, 1)  # Mirror the frame
#     debug_frame = copy.deepcopy(frame)

#     # Convert the frame to RGB (MediaPipe requires RGB)
#     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     # Perform hand detection
#     results = hands.process(frame_rgb)

#     # If hands are detected, draw landmarks on the frame
#     if results.multi_hand_landmarks:
#         for hand_landmarks, handedness in zip(results.multi_hand_landmarks, results.multi_handedness):
#             # Calculate the landmark list for each hand
#             Landmark_list = calc_landmark_list(debug_frame, hand_landmarks)

#             # Pre-process the landmark list (e.g., normalize)
#             pre_processed_landmark_list = pre_process_landmark(Landmark_list) 

#             if capturing and mode == 2:
#                 # Log the pre-processed landmark list
#                 print(pre_processed_landmark_list)

#                 # Increase the capture count
#                 capture_count += 1

#                 if capture_count > max_captures:
#                     # Stop capturing once 10 landmarks have been captured
#                     capturing = False
#                     capture_count = 0  # Reset the counter

#             if number == 0 and mode == 2 and not capturing:
#                 # Start capturing after pressing 0 once, only in mode 2
#                 capturing = True
#                 capture_count = 1  # Start the capture count at 1


#             # Draw the landmarks
#             mp.solutions.drawing_utils.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

#     # Display instructions
#     cv2.putText(frame, 'Press esc to exit ', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
#     cv2.putText(frame, f'Capturing: {capturing}', (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
#     cv2.imshow('Frame', frame)

# # Release the capture object and close windows
# cap.release()
# cv2.destroyAllWindows()

# %%
# import cv2
# import mediapipe as mp
# import os
# import csv
# import copy
# import itertools  # You missed importing itertools

# # Initialize video capture
# cap = cv2.VideoCapture(0)

# # Check if the camera opened successfully
# if not cap.isOpened():
#     print("Error: Unable to access the camera.")
#     exit()

# # Initialize MediaPipe Hands
# mp_hands = mp.solutions.hands
# hands = mp_hands.Hands(
#     static_image_mode=True,  # Whether to process each frame as a static image
#     max_num_hands=1,  # Number of hands to detect
#     min_detection_confidence=0.7,  # Minimum confidence value for detecting hands
#     min_tracking_confidence=0.5  # Minimum confidence value for hand tracking
# )

# # Initialize variables
# mode = 0
# capture_count = 0  # Counter for number of captures
# max_captures = 10  # Maximum number of captures
# capturing = False  # Flag to indicate if we are in capturing mode

# def select_mode(key, mode):
#     number = -1

#     if 48 <= key <= 57:  # 0 ~ 9
#         number = key - 48
#     if key == 110:  # n
#         mode = 0
#     if key == 107:  # k
#         mode = 1
#     if key == 115:  # s
#         mode = 2
#     return number, mode

# def logging_csv(number, mode, landmark_list): 
#     if mode == 2 and (0 <= number <= 9):  # Only write when mode is 2
#         csv_path = 'new_keypoint_1.csv'  # CSV file for mode 2

#         # Check if the file exists, if not, create it
#         if not os.path.exists(csv_path):
#             print(f"Creating CSV file at {csv_path}")  # Debug print
#             with open(csv_path, 'w', newline="") as f:
#                 writer = csv.writer(f)
#                 #writer.writerow(['Label', *['Landmark_' + str(i) for i in range(1, 22)]])  # Header with landmark columns

#         # Append the data to the CSV file
#         with open(csv_path, 'a', newline="") as f:
#             writer = csv.writer(f)
#             writer.writerow([number, *landmark_list])  # Write number and landmarks
#             print(f"Data written to {csv_path}")  # Debug print
     
#     return

# def pre_process_landmark(landmark_list):
#     temp_landmark_list = copy.deepcopy(landmark_list)

#     # Convert to relative coordinates
#     base_x, base_y = 0, 0
#     for index, landmark_point in enumerate(temp_landmark_list):
#         if index == 0:
#             base_x, base_y = landmark_point[0], landmark_point[1]

#         temp_landmark_list[index][0] = temp_landmark_list[index][0] - base_x
#         temp_landmark_list[index][1] = temp_landmark_list[index][1] - base_y

#     # Convert to a one-dimensional list
#     temp_landmark_list = list(itertools.chain.from_iterable(temp_landmark_list))

#     # Normalization
#     max_value = max(list(map(abs, temp_landmark_list)))

#     def normalize_(n):
#         return n / max_value

#     temp_landmark_list = list(map(normalize_, temp_landmark_list))

#     return temp_landmark_list

# def calc_landmark_list(image, landmarks):
#     image_width, image_height = image.shape[1], image.shape[0]

#     landmark_point = []

#     # Keypoint
#     for _, landmark in enumerate(landmarks.landmark):
#         landmark_x = min(int(landmark.x * image_width), image_width - 1)
#         landmark_y = min(int(landmark.y * image_height), image_height - 1)

#         landmark_point.append([landmark_x, landmark_y])

#     return landmark_point

# row_10 = []

# while True:
#     """Process Key (ESC: end)"""
#     key = cv2.waitKey(10)
#     if key == 27:  # ESC
#         break
#     number, mode = select_mode(key, mode)

#     ret, frame = cap.read()
#     if not ret:
#         print("Failed to capture frame. Exiting.")
#         break

#     frame = cv2.flip(frame, 1)  # Mirror the frame
#     debug_frame = copy.deepcopy(frame)

#     # Convert the frame to RGB (MediaPipe requires RGB)
#     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     # Perform hand detection
#     results = hands.process(frame_rgb)

#     # If hands are detected, draw landmarks on the frame
#     if results.multi_hand_landmarks:
#         for hand_landmarks, handedness in zip(results.multi_hand_landmarks, results.multi_handedness):
#             # Calculate the landmark list for each hand
#             Landmark_list = calc_landmark_list(debug_frame, hand_landmarks)

#             # Pre-process the landmark list (e.g., normalize)
#             pre_processed_landmark_list = pre_process_landmark(Landmark_list) 
#             if capturing and mode == 2:
#                 # Log the pre-processed landmark list
#                 print(pre_processed_landmark_list)


#                 # Increase the capture count
#                 capture_count += 1

#                 if capture_count > max_captures:
#                     # Stop capturing once 10 landmarks have been captured
#                     capturing = False
#                     logging_csv(number, mode, pre_processed_landmark_list)  # Save to CSV
#                     capture_count = 0  # Reset the counter
#                     row_10.append(pre_processed_landmark_list)
            
#             if number == 0 and mode == 2 and not capturing:
#                 # Start capturing after pressing 0 once, only in mode 2
#                 capturing = True
#                 capture_count = 1  # Start the capture count at 1

#             # Draw the landmarks
#             mp.solutions.drawing_utils.draw_landmarks(frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

#     # Display instructions
#     cv2.putText(frame, 'Press esc to exit ', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
#     cv2.putText(frame, f'Capturing: {capturing}', (10, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3)
#     cv2.imshow('Frame', frame)

# # Release the capture object and close windows
# cap.release()
# cv2.destroyAllWindows()
